# %%
import pandas as pd
from os import path

table = pd.read_table('genes.fpkm_tracking', index_col=4)
table_fbgn = pd.read_table('genes.fpkm_tracking', index_col=0)
endswith_fpkm = lambda x: x.endswith('_FPKM')

# %%
import matplotlib as mpl
#print [(param, mpl.rcParams[param]) for param in mpl.rcParams if param.startswith('font.')]
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['font.sans-serif'] = ['Arial']

# %%
fpkms = table.select(endswith_fpkm, 1)
fpkms_fbgn = table_fbgn.select(endswith_fpkm, 1)

# %%
highests = argmax(fpkms.as_matrix(), axis=1)
lowests = argmin(fpkms.as_matrix(), axis=1)

# %%
mkdir FlyExpressMaternal
# Out:
# mkdir: FlyExpressMaternal: File exists

# %%
matlist = set([line.strip() for line in open('matonly.txt')])

# %%
outfiles = [open(path.join('FlyExpressMaternal', column.replace('_FPKM', '') + '.txt'), 'w') for column in fpkms.columns]
for gene, highest, lowest in zip(fpkms.index, highests, lowests):
    if gene not in matlist: continue
    if fpkms.ix[gene][highest] > 2 * fpkms.ix[gene][lowest]:
        outfiles[highest].write(str(table.ix[gene]['tracking_id']) + '\n')
[f.close() for f in outfiles]
# Out:
# [None, None, None, None, None, None]

# %%
genediff = pd.read_table('gene_exp.diff')

# %%
is_diff = genediff[genediff.significant == 'yes'].select(lambda x: genediff.ix[x]['gene'] in matlist)

# %%
is_diff.sort(columns='log2(fold_change)')
# Out:
#             test_id      gene_id     gene                      locus sample_1 sample_2 status     value_1     value_2  log2(fold_change)  test_stat   p_value   q_value significant
# 61821   FBgn0262975  FBgn0262975      cnc  dmel_3R:18999594-19052430      AAA        P     OK   48.945800    0.840337           -5.86407    4.28694  0.000018  0.005046         yes
# 169735  FBgn0085281  FBgn0085281  CG34252  dmel_3L:18063389-18066482      AAA      PPP     OK   27.528700    0.887829           -4.95451    3.89420  0.000099  0.020037         yes
# 185416  FBgn0085281  FBgn0085281  CG34252  dmel_3L:18063389-18066482       AA      PPP     OK   26.753500    0.887829           -4.91330    3.91473  0.000091  0.018660         yes
# 201097  FBgn0085281  FBgn0085281  CG34252  dmel_3L:18063389-18066482        A      PPP     OK   20.900300    0.887829           -4.55710    3.66938  0.000243  0.039793         yes
# 47341   FBgn0001233  FBgn0001233    Hsp83    dmel_3L:3192968-3197631      AAA        P     OK  348.947000   22.064000           -3.98324    7.16691  0.000000  0.000000         yes
# 94384   FBgn0001233  FBgn0001233    Hsp83    dmel_3L:3192968-3197631      AAA       PP     OK  348.947000   27.616200           -3.65942    5.43802  0.000000  0.000043         yes
# 52019   FBgn0032400  FBgn0032400   CG6770  dmel_2L:12045345-12046100      AAA        P     OK   38.920000    3.228520           -3.59157    3.77621  0.000159  0.029023         yes
# 48129   FBgn0010316  FBgn0010316      dap    dmel_2R:5599828-5603607      AAA        P     OK   14.324500    1.341550           -3.41651    4.43552  0.000009  0.002901         yes
# 16767   FBgn0010316  FBgn0010316      dap    dmel_2R:5599828-5603607      AAA        A     OK   14.324500    1.447680           -3.30666    4.14948  0.000033  0.008490         yes
# 198225  FBgn0040056  FBgn0040056  CG17698  dmel_3L:23731059-23742158        A      PPP     OK    0.514691   15.274000            4.89122   -3.70818  0.000209  0.035685         yes
# 183769  FBgn0051641  FBgn0051641     stai    dmel_2L:6100376-6124653       AA      PPP     OK    0.879170   26.477500            4.91248   -3.74248  0.000182  0.032360         yes
# 215131  FBgn0051641  FBgn0051641     stai    dmel_2L:6100376-6124653        P      PPP     OK    0.852153   26.477500            4.95751   -3.86511  0.000111  0.021850         yes
# 203920  FBgn0000182  FBgn0000182     BicC  dmel_2L:16042031-16048626        P      PPP     OK    0.407361   13.445000            5.04462   -4.33694  0.000014  0.004249         yes
# 220018  FBgn0002962  FBgn0002962      nos  dmel_3R:14979818-14988000       PP      PPP     OK    4.745460  240.831000            5.66533   -3.90973  0.000092  0.018920         yes
# 158628  FBgn0016053  FBgn0016053      pgc  dmel_2R:18217230-18220320      AAA      PPP     OK   10.295100  606.277000            5.87995   -4.01061  0.000061  0.014068         yes
# 221352  FBgn0016053  FBgn0016053      pgc  dmel_2R:18217230-18220320       PP      PPP     OK    8.673920  606.277000            6.12715   -5.37540  0.000000  0.000056         yes
# 188784  FBgn0003401  FBgn0003401      shu  dmel_2R:19728983-19730802        A      PPP     OK    0.221099   17.193000            6.28099   -4.86887  0.000001  0.000525         yes
# 220146  FBgn0003401  FBgn0003401      shu  dmel_2R:19728983-19730802       PP      PPP     OK    0.212259   17.193000            6.33986   -3.67708  0.000236  0.038889         yes
# 157294  FBgn0002962  FBgn0002962      nos  dmel_3R:14979818-14988000      AAA      PPP     OK    2.430130  240.831000            6.63084   -3.64621  0.000266  0.042776         yes
# 204465  FBgn0003401  FBgn0003401      shu  dmel_2R:19728983-19730802        P      PPP     OK    0.050936   17.193000            8.39892   -3.91312  0.000091  0.018740         yes
# 174309  FBgn0016053  FBgn0016053      pgc  dmel_2R:18217230-18220320       AA      PPP     OK    1.127400  606.277000            9.07083   -5.31058  0.000000  0.000075         yes
# 205671  FBgn0016053  FBgn0016053      pgc  dmel_2R:18217230-18220320        P      PPP     OK    1.074470  606.277000            9.14021   -6.68261  0.000000  0.000000         yes
# 189990  FBgn0016053  FBgn0016053      pgc  dmel_2R:18217230-18220320        A      PPP     OK    1.071470  606.277000            9.14425   -7.81299  0.000000  0.000000         yes

# %%
figure(figsize=(3.0,2.2))
lists = [[] for i in range(6)]
for gene in is_diff.gene.unique():
    lists[argmax(fpkms.ix[gene])].append(gene)
print hist([argmax(fpkms.ix[i]) for i in is_diff.gene.unique()], bins=6)
xlim(0,5)
ylabel('Significant genes with\npeak expression in slice')
xticks([0.5, 4.5], ["Anterior", "Posterior"])

tight_layout()
savefig('figures/MaternalSignificant.eps',dpi=300)



print '\n-----\n'.join('\n'.join(l) for l in lists)
# Out:
# (array([ 7,  3,  1,  1,  1, 21]), array([ 0.        ,  0.83333333,  1.66666667,  2.5       ,  3.33333333,
#         4.16666667,  5.        ]), <a list of 6 Patch objects>)
# Hsp83
# CG32251
# msps
# CG6770
# cnc
# rdx
# CG34252
# -----
# Nek2
# bmm
# BEAF-32
# -----
# hb
# -----
# Alh
# -----
# cad
# -----
# dap
# nos
# pgc
# mthl1
# gcl
# stai
# Hsp27
# PyK
# qua
# shu
# mtrm
# Rca1
# mge
# CG17698
# armi
# BicC
# egl
# exu
# gnu
# CG14814
# Tpi

# %% [markdown]
# Mike's Big Idea
# ===============
#
#
# Known patterned genes, with their images, then the plots of their expression across my slices

# %%
import pandas as pd
import matplotlib as mpl
#print [(param, mpl.rcParams[param]) for param in mpl.rcParams if param.startswith('font.')]
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['font.sans-serif'] = ['Arial']

# %%
BDGP_names = pd.read_csv('figures/insitu_images.csv')
fig2_list = sorted([line.strip() for line in open('fig2_list.txt')])

# %%
st_5_with_lat = BDGP_names[(BDGP_names['stage'] == 2) & (BDGP_names['view'] == 'lateral')]

# %%
table = pd.read_table('genes.fpkm_tracking', index_col=4)
endswith_fpkm = lambda x: x.endswith('_FPKM')
fpkms = table.select(endswith_fpkm, 1)

# %%
import urllib, time
from os import path
def imget(imname):
    """ Use cached, or fetch an image from FlyExpress

Assumes that the image name is one from BDGP, in which case
it's pretty easy to look at the source of the FlyExpress
report pages and see what the format is. 

"""
    im_basename = path.splitext(path.basename(imname))[0]
    filename = path.join('figures', 'BDGP', im_basename+'.bmp')
    if not path.exists(filename):
        base_web = "http://www.flyexpress.net/ZOOX4_DBImages/BDGP/thumbnails/%s_s.bmp"
        print "1 second delay to avoid spamming server"
        time.sleep(1)
        urllib.urlretrieve(base_web % im_basename, filename)
    return imread(filename)

# %%
st_5_with_lat[st_5_with_lat['Name2'] == 'hb']
# Out:
#        Gene_name Name2 Name3         FBgn SomethingElse                     imgfile  stage     view    ap_invert hilo
# 105852    CG9786    hb    hb  FBgn0001180    LD34229-tf  img_dir_14/insitu14890.jpe      2  lateral  AP_inverted  low
# 105853    CG9786    hb    hb  FBgn0001180    LD34229-tf  img_dir_14/insitu14891.jpe      2  lateral          NaN  low
# 105854    CG9786    hb    hb  FBgn0001180    LD34229-tf  img_dir_14/insitu14892.jpe      2  lateral          NaN  low
# 105855    CG9786    hb    hb  FBgn0001180    LD34229-tf  img_dir_14/insitu14893.jpe      2  lateral          NaN  low
# 105856    CG9786    hb    hb  FBgn0001180    LD34229-tf  img_dir_14/insitu14894.jpe      2  lateral  AP_inverted  low
# 105857    CG9786    hb    hb  FBgn0001180    LD34229-tf  img_dir_14/insitu14895.jpe      2  lateral  AP_inverted  low
# 105858    CG9786    hb    hb  FBgn0001180    LD34229-tf  img_dir_14/insitu14896.jpe      2  lateral  DV_inverted  low
# 105860    CG9786    hb    hb  FBgn0001180    LD34229-tf  img_dir_14/insitu14898.jpe      2  lateral  DV_inverted  low
# 105861    CG9786    hb    hb  FBgn0001180    LD34229-tf  img_dir_14/insitu14909.jpe      2  lateral          NaN  low

# %%
fpkms.index
# Out:
# Index([nan, FBgn0000003, FBgn0000008, ..., FBtr0334013, FBtr0334014,
#        FBtr0334031], dtype=object)

# %%
def plot_gene(gene_name,
              subplot_rows = 1, subplot_cols = 2, subplot_num = 1):
    if gene_name.startswith('FBgn'):
        my_table = fpkms_fbgn
    else:
        my_table = fpkms
    subplot(subplot_rows, subplot_cols, subplot_num)
    shown = False
    for j, data_row in st_5_with_lat[st_5_with_lat['Name2'] == gene_name].iterrows():
        try:
            imdat = imget(data_row['imgfile'])
            imshow(imdat, origin='lower')
            shown = True
            break
        except IOError:
            pass
    if not shown:
        print "Can't find image for", gene_name
    #rows, cols, rgb = shape(imdat)
    ax = gca()
    xticks([], [])
    yticks([], [])
    for spine in ax.spines.itervalues():
        spine.set_visible(False)
    ylabel(gene_name)
    subplot(subplot_rows, subplot_cols, subplot_num + 1)
    if gene_name in my_table.index:
        ax = gca()
        plot(linspace(0, 100, len(my_table.columns), False), my_table.ix[gene_name])
        xticks([], [])
        old_ticks = yticks()[0]
        yticks([0, old_ticks[-1]])
        ax.yaxis.tick_right()
    else:
        print "Can't find data for", gene_name

# %%
figure(figsize(4,3))
plot_gene('FBgn0001254')
# Out:
# Can't find image for FBgn0001254

# %%
buf = 10
fig2_list = sorted([line.strip() for line in open('fig2_list.txt')])
num_genes = len(fig2_list)

aspect = 1/2.
fig_cols = 4.0 #max(floor(sqrt(num_genes)*aspect), 1)
fig_rows = ceil(num_genes / fig_cols)

fig_cols *= 2 # For both the image and the plot

fig = figure(figsize=(6.813, 7.426),dpi=300)
all_axes = []
for i, name in enumerate(fig2_list):
    ax1 = fig.add_subplot(fig_rows, fig_cols, 2*i+1)
    shown = False
    for j, data_row in st_5_with_lat[st_5_with_lat['Name2'] == name].iterrows():
        try:
            imdat = imget(data_row['imgfile'])
            ax1.imshow(imdat, origin='lower')
            shown = True
            break
        except IOError:
            pass
    if not shown:
        print "Can't find image for", name
    rows, cols, rgb = shape(imdat)
    ax = gca()
    xticks([], [])
    yticks([], [])
    for spine in ax.spines.itervalues():
        spine.set_visible(False)
    ylabel(name)
    ax2 = fig.add_subplot(fig_rows, fig_cols, 2*i+2)
    if name in fpkms.index:
        ax2.plot(linspace(buf, cols-buf, len(fpkms.columns), False), fpkms.ix[name])
        xticks([], [])
        old_ticks = yticks()[0]
        yticks([0, old_ticks[-1]])
        ax2.yaxis.tick_right()
    else:
        print "Can't find data for", name
    all_axes.append((ax1, ax2))
tight_layout()

for ax1, ax2 in all_axes:
    bbox1 = ax1.get_position()
    bbox2 = ax2.get_position()
    extra_width = (bbox2.x0 - bbox1.x1)/2 * 0.9
    ax1.set_position([bbox1.x0, bbox1.y0, 
                        bbox1.width+extra_width, bbox1.height])
    ax2.set_position([bbox2.x0 - extra_width, bbox2.y0,
                      bbox2.width+extra_width, bbox2.height])

#old_pos = ax.get_position()
#ax.set_position([0, old_pos.y0, old_pos.width, old_pos.height])

savefig('figures/fig2.pdf',dpi=300)
savefig('figures/fig2.tiff',dpi=300)
savefig('figures/fig2.png',dpi=300)

# %%
figure(figsize=(4,3))
plot_gene('Doc3')
# Out:
# 1 second delay to avoid spamming server

# %%
for sublist in lists:
    for gene in sublist:
        figure(figsize=(4,3))
        plot_gene(gene)
        ax = gca()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-56d93bdf659d> in <module>()
# ----> 1 for sublist in lists:
#       2     for gene in sublist:
#       3         figure(figsize=(4,3))
#       4         plot_gene(gene)
#       5         ax = gca()
#
# NameError: name 'lists' is not defined

# %%
NoFlyExpress = ['CG32251', 'CG6770', 'CG34252', 'BicC', 'mthl1', 'stai', 'mtrm',]

num_genes = len(NoFlyExpress)

aspect = 1.5
fig_cols = max(floor(sqrt(num_genes)*aspect), 1)
fig_rows = ceil(num_genes / fig_cols)

#fig_cols *= 2 # For both the image and the plot

figure(figsize=(3.27,2.5),dpi=900)


for i, gene in enumerate(NoFlyExpress):
    #plot_gene(gene, fig_rows, fig_cols, i*2+1)
    subplot(fig_rows, fig_cols, i+1)
    ax = gca()
    plot(fpkms.ix[gene])
    xticks([])
    yt_pos, yt_lab = yticks()
    yticks([yt_pos[0], yt_pos[-1]])
    ylabel(gene)
    ax.yaxis.tick_right()
    
tight_layout()    
    
savefig('figures/maternal_noFlyEx.pdf',dpi=300)

# %% [markdown]
# # All Differential Genes

# %%
mine = set(line.strip() for line in open('DiffExp/AllDiffExpWTGenes.txt'))
theirs = set(line.strip() for line in open('DiffExp/BDGP_subset_names.txt'))

# %%
len(mine.intersection(theirs))
# Out:
# 30

# %%
len(mine)
# Out:
# 176

# %%
len(theirs)
# Out:
# 201

# %%
plot_gene('bun')

# %%
hist([max(fpkms.ix[gene]) for gene in theirs.difference(mine) if gene in fpkms.index], arange(0,100))
print sum(1 for gene in theirs.difference(mine) if gene in fpkms.index and max(fpkms.ix[gene]) < 20)
len(theirs.difference(mine))
# Out:
# 80
# 171

# %%
x = [gene for gene in theirs.difference(mine) if gene in fpkms.index and max(fpkms.ix[gene]) > 20]
print x
print len(x)
# Out:
# ['dbo', 'scw', 'CG32043', 'th', 'Mkp3', 'CG32473', 'bib', 'neur', 'emc', 'Egfr', 'Eip71CD', 'sced', 'CG13784', 'asp', 'Hsf', 'dlp', 'Cctgamma', 'CG3036', 'kel', 'run', 'Lis-1', 'CG4455', 'CG30118', 'CG1815', 'CBP', 'Bsg25D', 'Pros54', 'CG5059', 'CG5522', 'CG6885', 'E2f', 'corto', 'CycE', 'Sep5', 'jing', 'Btk29A', 'DnaJ-1', 'lok', 'aret', 'Nrt', 'CG8036', 'bnb', 'Thiolase', 'roX1', 'CG1103', 'for', 'sna', 'tld', 'Ance', 'CG14937', 'zfh1', 'Pfrx', 'bun']
# 53

# %%
[gene for gene in theirs.difference(mine) if gene not in fpkms.index]
# Out:
# ['',
#  'CG7663',
#  'CG11798',
#  'CG11347',
#  'CG6854',
#  'CG7986',
#  'CG5403',
#  'CG32372',
#  'Cyp306a1',
#  'CG32177',
#  'CG7312',
#  'CG4827',
#  'CG8603',
#  'CG9615',
#  'Tkr',
#  'loner',
#  'Traf1',
#  'Alhambra',
#  'CG32796',
#  'CG9598',
#  'argos',
#  'CG5249',
#  'CG10728',
#  'CG10724',
#  '26-29kD-proteinase',
#  'CG14430',
#  'BcDNA:GH10270',
#  'CG13290',
#  'CG1962',
#  'CG30426',
#  'CG12026',
#  'CG9924',
#  'CG6464',
#  'CG13620',
#  'CG7359',
#  'CG5410',
#  'FB{}1097',
#  'CG31133']
