# %%
run ~/Documents/EisenLabStuff/Code/BayesMatch.py summary_with_bcd_with_conf.tsv
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/pacombs/.python/lib/python2.7/site-packages/ipython-0.13.1-py2.7.egg/IPython/utils/py3compat.pyc in execfile(fname, *where)
#     176             else:
#     177                 filename = fname
# --> 178             __builtin__.execfile(filename, *where)
#
# /Users/pacombs/Documents/EisenLabStuff/Code/BayesMatch.py in <module>()
#      97
#      98
# ---> 99 args = parse_args()
#     100 frame = pd.read_table(args.fname)
#     101 frame = frame.dropna(how='any')
#
# /Users/pacombs/Documents/EisenLabStuff/Code/BayesMatch.py in parse_args()
#      91     args = parser.parse_args()
#      92     print args.set
# ---> 93     for i, set in enumerate(args.set):
#      94         args.set[i] = tuple(set.split(','))
#      95     print args.set
#
# TypeError: 'NoneType' object is not iterable
# None

# %%
run ~/Documents/EisenLabStuff/Code/BayesMatch.py --colormap gist_rainbow --set A,P genes.fpkm_tracking -W 6.83 -H 1.5
# Out:
# ['A,P']
# [('A', 'P')]
# ------------------------------------------------------------
#
# ('A', 'P')
# ------------------------------------------------------------
# Found columns:  ['AAA_FPKM', 'AA_FPKM', 'A_FPKM', 'P_FPKM', 'PP_FPKM', 'PPP_FPKM']
# <div class="pb" id="f735f189-e3a4-491a-9262-339d3acda05f"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Susan: ('A', 'P'):</td>
# <td class="pb_widget"><div id="79a60564-d390-4005-87a0-c0a723f77e3d">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="a2be61ef-d762-4c1d-aa6a-b390e9a55d33"></div>
#         <script type="text/javascript">
#             $("div#a2be61ef-d762-4c1d-aa6a-b390e9a55d33").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="94900d55-950f-48d7-8cb6-e3e27a2d5450">ETA:  --:--:--</div></td>
# </tr></table><div>
# Best hit in  ../susan/by_cycle/cyc_14b.txt
# <div class="pb" id="ea63f28e-3bd5-4550-ab23-953cccb17744"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 0:</td>
# <td class="pb_widget"><div id="72a80c85-01e4-4747-9f49-64cdf0b3dbff">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="81a8392a-2990-4044-927c-472171189ec8"></div>
#         <script type="text/javascript">
#             $("div#81a8392a-2990-4044-927c-472171189ec8").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="e5757244-e322-4c1a-b5e4-15d1729ccde4">ETA:  --:--:--</div></td>
# </tr></table><div>
# Saving to:  /Volumes/Macintosh HD/Users/pcombs/Documents/EisenLabStuff/data/Fall2012/figures/Sample_AP_T0.pdf
# In time slice
#  0
# Mode position [ 29 104 157 232 315 376]
# Mean position [27.222780826064092, 100.06534188689155, 155.83895764492974, 237.00087412021347, 312.37691330445193, 376.1859483625704]
# <div class="pb" id="8d7a161d-b043-4d43-9c79-78ba57f53c2b"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 1:</td>
# <td class="pb_widget"><div id="626343b4-397f-453f-bea9-2729a5731593">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="cbe9e70f-17b4-49e1-8ac2-377e502f40a6"></div>
#         <script type="text/javascript">
#             $("div#cbe9e70f-17b4-49e1-8ac2-377e502f40a6").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="5db7acfd-f1d9-43db-ba2b-c37d2e75f5bd">ETA:  --:--:--</div></td>
# </tr></table><div>
# Saving to:  /Volumes/Macintosh HD/Users/pcombs/Documents/EisenLabStuff/data/Fall2012/figures/Sample_AP_T1.pdf
# In time slice
#  1
# Mode position [ 10  34 162 243 280 399]
# Mean position [11.243603487893164, 33.139650148740131, 168.01567607414708, 239.52659685906403, 282.82139105031854, 392.85435291493269]
# <div class="pb" id="0ca24b0d-ec11-49c6-8b72-e27647c8ad06"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 2:</td>
# <td class="pb_widget"><div id="d6c00366-2446-4b89-afec-c59e4df47f76">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="fe2e2e1f-f2c3-4826-a329-8c7a2b715c06"></div>
#         <script type="text/javascript">
#             $("div#fe2e2e1f-f2c3-4826-a329-8c7a2b715c06").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="29851b09-c282-4715-bc16-505c78c3121b">ETA:  --:--:--</div></td>
# </tr></table><div>
# Saving to:  /Volumes/Macintosh HD/Users/pcombs/Documents/EisenLabStuff/data/Fall2012/figures/Sample_AP_T2.pdf
# In time slice
#  2
# Mode position [ 34 112 141 243 298 399]
# Mean position [27.446088458560581, 103.4509336791333, 151.89649456756956, 240.83366567608601, 302.76653852621587, 382.27806870119338]
# <div class="pb" id="5ea29f12-f8c7-4422-9b69-64b18f25e7ac"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 3:</td>
# <td class="pb_widget"><div id="bee2e5d6-bb77-43ec-bfd2-ca812cbf6ef9">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="4679e574-77b0-4d1c-a4a6-3742d613b494"></div>
#         <script type="text/javascript">
#             $("div#4679e574-77b0-4d1c-a4a6-3742d613b494").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="6bca1f16-9d70-4359-ab68-4550c3d280d6">ETA:  --:--:--</div></td>
# </tr></table><div>
# Saving to:  /Volumes/Macintosh HD/Users/pcombs/Documents/EisenLabStuff/data/Fall2012/figures/Sample_AP_T3.pdf
# In time slice
#  3
# Mode position [  8 109 320 229 288 380]
# Mean position [14.18729098352169, 101.16287658692129, 315.10812614083363, 233.10771190204798, 286.12979998337727, 382.87938345995832]
# <div class="pb" id="1632d922-6e39-4096-b6ff-113229552381"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 4:</td>
# <td class="pb_widget"><div id="40b78749-2305-450d-8ae0-2fdafd0d292e">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="e691637b-04e6-45e4-b1fd-d194b028e2ab"></div>
#         <script type="text/javascript">
#             $("div#e691637b-04e6-45e4-b1fd-d194b028e2ab").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="c4a8a645-8472-45ad-afaf-147cff162a66">ETA:  --:--:--</div></td>
# </tr></table><div>
# Saving to:  /Volumes/Macintosh HD/Users/pcombs/Documents/EisenLabStuff/data/Fall2012/figures/Sample_AP_T4.pdf
# In time slice
#  4
# Mode position [ 37 109 164 229 288 382]
# Mean position [36.403919534346365, 103.50203447110557, 172.51174077394614, 230.8651421650319, 285.24964193073248, 377.49759444743177]
# <div class="pb" id="2006301f-32d0-4dc5-83a9-40aa7cc52291"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 5:</td>
# <td class="pb_widget"><div id="cda828f1-efa9-41c3-9dda-7638963fd2d0">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="b057afe2-33c5-40a8-a1ef-787d7d35d6bb"></div>
#         <script type="text/javascript">
#             $("div#b057afe2-33c5-40a8-a1ef-787d7d35d6bb").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="0ab4d3a4-5000-4842-b0ad-8f1a2468be13">ETA:  --:--:--</div></td>
# </tr></table><div>
# Saving to:  /Volumes/Macintosh HD/Users/pcombs/Documents/EisenLabStuff/data/Fall2012/figures/Sample_AP_T5.pdf
# In time slice
#  5
# Mode position [ 35 115 181 229 288 384]
# Mean position [33.54192760158066, 116.85034559941512, 181.14181270601915, 229.05954222023649, 286.6663128831737, 385.08798889312919]

# %%
run -p ~/Documents/EisenLabStuff/Code/BayesMatch.py --set CaS1 --set CaS2 --set CaS3 summary_with_bcd_with_conf.tsv
# Out:
# ['CaS1', 'CaS2', 'CaS3']
# [('CaS1',), ('CaS2',), ('CaS3',)]
# ------------------------------------------------------------
#
# ('CaS1',)
# ------------------------------------------------------------
# Found columns:  ['CaS1A_FPKM', 'CaS1B_FPKM', 'CaS1C_FPKM', 'CaS1D_FPKM', 'CaS1E_FPKM', 'CaS1F_FPKM']
# <div class="pb" id="be558089-eeb3-4490-ba1f-34cb9f83847b"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Susan: ('CaS1',):</td>
# <td class="pb_widget"><div id="ca02ec69-b971-4ad2-be51-20a268533cee">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="4d0c45c9-191a-490d-9a2c-b457f2351416"></div>
#         <script type="text/javascript">
#             $("div#4d0c45c9-191a-490d-9a2c-b457f2351416").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="1a12f07d-dfc3-48ab-9a53-ef0eb96b156b">ETA:  --:--:--</div></td>
# </tr></table><div>
# Best hit in  ../susan/by_cycle/cyc_14d.txt
# <div class="pb" id="fa65a5fe-ddb1-497c-b03a-097182f88c4f"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 0:</td>
# <td class="pb_widget"><div id="5d62e966-0e8c-42dd-9a7d-a68d0ec5ee7a">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="93e0c916-e785-4005-bda2-5ba5ac463703"></div>
#         <script type="text/javascript">
#             $("div#93e0c916-e785-4005-bda2-5ba5ac463703").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="055906c8-a843-49da-a6dd-01e839b39fdd">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 0
# Mode position [419 419  95 313 407 419]
# Mean position [394.66488207249262, 418.93882322475014, 93.543082963417802, 298.44561846800372, 406.31949571798873, 418.05419012154437]
# <div class="pb" id="faf5b925-0b94-4457-b67a-075cc839942f"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 1:</td>
# <td class="pb_widget"><div id="1778ddc0-6fde-4c41-ac04-63934da4197f">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="a5e08b14-de3f-47e2-b5ce-c461253c31be"></div>
#         <script type="text/javascript">
#             $("div#a5e08b14-de3f-47e2-b5ce-c461253c31be").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="075bc852-4537-4177-9c3a-8818b1cbe38e">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 1
# Mode position [419 419 330 324 386 418]
# Mean position [409.07366958386376, 418.86006649384933, 331.1547307932039, 224.6038781236071, 387.76443361871043, 417.14091314253699]
# <div class="pb" id="435a5ba0-1b03-45dc-9459-ed55722af385"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 2:</td>
# <td class="pb_widget"><div id="fdb5a381-3965-4610-af3e-93df32617813">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="2ac7bc5c-7640-40d2-97bd-24f0bc594f4d"></div>
#         <script type="text/javascript">
#             $("div#2ac7bc5c-7640-40d2-97bd-24f0bc594f4d").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="a4548676-e54a-485b-8038-672f35992786">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 2
# Mode position [419 419 326  67 386 419]
# Mean position [418.87308648017233, 418.82387884920723, 325.2423320726819, 110.29273260516709, 386.58521340939865, 418.4561405205551]
# <div class="pb" id="b470e94d-a257-4af1-848f-58414bfa3694"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 3:</td>
# <td class="pb_widget"><div id="2301c371-7f47-4f74-b0a4-aa65b7e1b2a2">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="9a913796-c1ed-41ca-bb99-54d0f1b96480"></div>
#         <script type="text/javascript">
#             $("div#9a913796-c1ed-41ca-bb99-54d0f1b96480").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="ae3d1b43-a4b8-4ef1-b644-8ac9b0fc930b">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 3
# Mode position [419 418 332 316 355 419]
# Mean position [403.75448767459301, 403.83659143138749, 332.64418208379573, 315.46455910414073, 353.15547884139767, 418.99712769605935]
# <div class="pb" id="38b0099f-12a0-4f6e-a29a-3beb792b98f2"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 4:</td>
# <td class="pb_widget"><div id="a3a4ceba-9529-4065-8bb1-5ba30de52278">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="9aa46c98-e4c5-481f-8415-561eb452c3ea"></div>
#         <script type="text/javascript">
#             $("div#9aa46c98-e4c5-481f-8415-561eb452c3ea").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="bcf71471-ca5b-4875-a568-abec69f0ff12">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 4
# Mode position [419   0 334  19 400 419]
# Mean position [417.41119353092489, 111.99094396665402, 335.6165394319961, 19.872961879666953, 400.62721293194329, 418.91726870430017]
# <div class="pb" id="95c97846-3bbe-4c80-adba-5b5a38fce492"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 5:</td>
# <td class="pb_widget"><div id="5b9fb4e2-ef10-407f-8da9-214b92558fb6">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="a2b90c9d-398b-4cb1-9f4b-efb0c87f2ce5"></div>
#         <script type="text/javascript">
#             $("div#a2b90c9d-398b-4cb1-9f4b-efb0c87f2ce5").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="020a3a3f-fc73-4a64-963c-e84eb1bc7bdf">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 5
# Mode position [419 416 317  13 390 419]
# Mean position [417.84514972176157, 416.35756109466263, 322.95420736017297, 13.896703048675807, 392.70350051384764, 418.99783403892144]
# ------------------------------------------------------------
# ('CaS2',)
# ------------------------------------------------------------
# Found columns:  ['CaS2A_FPKM', 'CaS2B_FPKM', 'CaS2C_FPKM', 'CaS2D_FPKM', 'CaS2E_FPKM', 'CaS2F_FPKM']
# <div class="pb" id="9f3ed12a-6034-48f9-af85-b0e9e74a65d2"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Susan: ('CaS2',):</td>
# <td class="pb_widget"><div id="bf1c0b01-839b-4d52-85a0-c797dc4890fc">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="92b88d86-df8c-47b8-b993-c2bc51cd1ae6"></div>
#         <script type="text/javascript">
#             $("div#92b88d86-df8c-47b8-b993-c2bc51cd1ae6").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="31c521eb-a150-4ce3-bab5-a2a0302302f8">ETA:  --:--:--</div></td>
# </tr></table><div>
# Best hit in  ../susan/by_cycle/cyc_14b.txt
# <div class="pb" id="d68276dd-a957-4a4b-93cf-ea138a6bb3e1"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 0:</td>
# <td class="pb_widget"><div id="c3e5f5e8-b028-4eab-a292-c487c35e05ca">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="6bbfc5ad-57a7-4c85-b066-90240a5247f1"></div>
#         <script type="text/javascript">
#             $("div#6bbfc5ad-57a7-4c85-b066-90240a5247f1").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="715a5772-00e3-42b3-94a5-cf0a97f0958d">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 0
# Mode position [ 28 107 163 249 312 348]
# Mean position [27.997618050916714, 183.0768753803859, 163.90826125870507, 241.39676643107171, 313.53274226966573, 352.18404539772547]
# <div class="pb" id="03823fb0-1251-4d63-a662-2b971b5154b3"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 1:</td>
# <td class="pb_widget"><div id="ae22e099-dc59-4cad-a339-e359c560d8f5">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="0c0e6863-bf01-49c2-bfcf-c65de278cbfa"></div>
#         <script type="text/javascript">
#             $("div#0c0e6863-bf01-49c2-bfcf-c65de278cbfa").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="f53f6a9a-2aad-4a88-b2f4-a7c275c91ac7">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 1
# Mode position [ 41 237 169 231 282 372]
# Mean position [40.984991955991866, 243.26858385867772, 168.93081480360172, 232.2485132644768, 267.94986219421213, 369.33642809923305]
# <div class="pb" id="12cd91b8-5790-44e3-82e0-adcdbd56ba52"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 2:</td>
# <td class="pb_widget"><div id="e44ec8e5-95ac-43f5-a87f-b1aaac8c1964">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="63e2fe08-32fa-4a5e-bd68-f4e5f74b318f"></div>
#         <script type="text/javascript">
#             $("div#63e2fe08-32fa-4a5e-bd68-f4e5f74b318f").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="185c65c9-84ec-4242-856e-2903a684038d">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 2
# Mode position [ 36 284 169 221 395 419]
# Mean position [34.962979765790081, 274.10259063388457, 168.06515379882435, 231.03902987589663, 367.07705666447345, 407.67647604857234]
# <div class="pb" id="aba0f051-83b6-4ce6-b6a1-f651f990a9c9"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 3:</td>
# <td class="pb_widget"><div id="c9e44177-2c0c-4a9a-bb35-840cc4d2d05d">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="db4a35f8-4fa8-4173-b10c-8b4e37d887c1"></div>
#         <script type="text/javascript">
#             $("div#db4a35f8-4fa8-4173-b10c-8b4e37d887c1").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="dfb2093a-920b-4a27-9192-147830997292">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 3
# Mode position [ 41 273 201 249 249 369]
# Mean position [44.220000638563924, 311.0678173031875, 200.23761459678391, 228.39251812066547, 246.39318769042987, 369.75041032390101]
# <div class="pb" id="17a05069-5fcf-4a1e-81c7-afda707c9675"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 4:</td>
# <td class="pb_widget"><div id="0bf25fb8-33bc-4f8b-a4b2-43b5449fc1c3">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="bfb8fe44-7fee-43dc-92e0-08659594f1fb"></div>
#         <script type="text/javascript">
#             $("div#bfb8fe44-7fee-43dc-92e0-08659594f1fb").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="3f0bcd12-ec01-4ce8-a18f-f984bca6901d">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 4
# Mode position [ 50 231 216 248 252 340]
# Mean position [51.766492627031155, 240.13976239343498, 168.63153891018803, 231.90589053462011, 250.85557627049366, 346.29801378958172]
# <div class="pb" id="542c197c-02c1-4eef-b4fb-f9e1171822f1"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 5:</td>
# <td class="pb_widget"><div id="f8a8089a-fc7b-4121-992e-071ddee4f45f">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="4ae26f16-a9dd-4767-8deb-9b45a19e1306"></div>
#         <script type="text/javascript">
#             $("div#4ae26f16-a9dd-4767-8deb-9b45a19e1306").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="1dd42070-da2d-4dee-a84d-2557e9b4be42">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 5
# Mode position [ 83 109 134  22 249 398]
# Mean position [82.16454907704491, 108.41563663743496, 135.3372336514818, 23.861597265526434, 254.58611625794353, 396.84830706352881]
# ------------------------------------------------------------
# ('CaS3',)
# ------------------------------------------------------------
# Found columns:  ['CaS3A_FPKM', 'CaS3B_FPKM', 'CaS3C_FPKM', 'CaS3D_FPKM', 'CaS3E_FPKM', 'CaS3F_FPKM']
# <div class="pb" id="f160f210-525b-4729-b49e-0f5daa994321"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Susan: ('CaS3',):</td>
# <td class="pb_widget"><div id="135e7a2e-b743-4e79-bf10-4961d17e1283">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="0b3b46ed-1547-4df4-b4d2-04269a851d1f"></div>
#         <script type="text/javascript">
#             $("div#0b3b46ed-1547-4df4-b4d2-04269a851d1f").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="8b123f35-0392-47b3-a9f5-7a854f560e24">ETA:  --:--:--</div></td>
# </tr></table><div>
# Best hit in  ../susan/by_cycle/cyc_14d.txt
# <div class="pb" id="a467412f-f035-4196-bab9-bc11c80379df"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 0:</td>
# <td class="pb_widget"><div id="ed040fe6-f258-4199-bf02-bb1f46a7c937">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="33012c48-4461-46b9-9181-938395a9c863"></div>
#         <script type="text/javascript">
#             $("div#33012c48-4461-46b9-9181-938395a9c863").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="f203e3b1-ae01-4f7f-92e6-85be3230de5a">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 0
# Mode position [417 417 214 412   0   0]
# Mean position [416.60546098369105, 417.19867695454997, 211.43601215764485, 261.38754374175824, 9.5539108518055578, 0.38488166551685099]
# <div class="pb" id="ed3ec980-e0d7-4adc-a253-548de1c8b16b"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 1:</td>
# <td class="pb_widget"><div id="bd7b2e37-52ad-4791-badb-70fe38eb5458">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="f09bcf96-019b-4927-8362-a8e310330f88"></div>
#         <script type="text/javascript">
#             $("div#f09bcf96-019b-4927-8362-a8e310330f88").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="517359ec-5b89-47e8-9fa6-3b210af93eb8">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 1
# Mode position [418   9 221 346  17   0]
# Mean position [417.6104414115992, 12.83580969857973, 227.60020191363787, 338.89229104656471, 21.207262793189237, 0.11889598163699451]
# <div class="pb" id="09d8c4e7-bb30-4103-9c1f-2cba1d8451cf"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 2:</td>
# <td class="pb_widget"><div id="e803c43d-a9f8-4b18-9aa5-3492215d19b1">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="11113daa-9036-4d2a-a653-4dcfa19e07a1"></div>
#         <script type="text/javascript">
#             $("div#11113daa-9036-4d2a-a653-4dcfa19e07a1").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="57db3f7a-b6a0-401b-a923-0229533491f2">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 2
# Mode position [415 417 168 416   0   2]
# Mean position [414.95212864702313, 405.78748367684915, 182.17716955518384, 413.01957472841985, 42.673639076559233, 1.7629039397306749]
# <div class="pb" id="c41878ee-4ffa-4cb8-bde0-a2c7b014c244"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 3:</td>
# <td class="pb_widget"><div id="0cb8ad2a-30a6-4546-b870-71573dacab0f">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="0bf6990f-e002-414a-a94c-2be095795f67"></div>
#         <script type="text/javascript">
#             $("div#0bf6990f-e002-414a-a94c-2be095795f67").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="de1abb0d-bd79-4790-a2ab-0d938ec3861d">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 3
# Mode position [404   3  74 158  52  13]
# Mean position [403.59897652931818, 3.0326223002545629, 74.643938327169778, 206.75431621264207, 47.295089726260876, 12.411826120730863]
# <div class="pb" id="116ed0a2-2821-4ec2-addb-20b671dbd0c0"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 4:</td>
# <td class="pb_widget"><div id="a8545812-701b-4265-8785-c239a1b0aa54">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="64e136dd-fd8a-4575-9a4d-a6542b0224f0"></div>
#         <script type="text/javascript">
#             $("div#64e136dd-fd8a-4575-9a4d-a6542b0224f0").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="0cab0417-fa34-410d-a156-0f75df991ae1">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 4
# Mode position [405   2 219 118  61  13]
# Mean position [405.5344254959179, 2.0926196986833694, 219.4161009561264, 138.79884176317546, 57.403431755064666, 15.359976221645676]
# <div class="pb" id="9398ae21-0ec9-485c-be02-e1d0ac8dccf9"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 5:</td>
# <td class="pb_widget"><div id="458cf3aa-62ee-4544-9afb-883b41243e7c">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="2477d0eb-3df2-4652-b9ad-43d346f9133b"></div>
#         <script type="text/javascript">
#             $("div#2477d0eb-3df2-4652-b9ad-43d346f9133b").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="e28dcf40-f5f5-4df3-a87a-6c43500bb1cc">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 5
# Mode position [  2   0 256 165  71  40]
# Mean position [1.5233416995730296, 0.11090320806561668, 255.72489203205362, 164.72649866138565, 76.33316449279387, 40.349557961649573]

# %%
run ~/Documents/EisenLabStuff/Code/BayesMatch.py --set Bcd with_bcd.fpkm_tracking
# Out:
# ['Bcd']
# [('Bcd',)]
# ------------------------------------------------------------
#
# ('Bcd',)
# ------------------------------------------------------------
# Found columns:  ['Bcd-AA_FPKM', 'Bcd-A_FPKM', 'Bcd-AP_FPKM', 'Bcd-P_FPKM', 'Bcd-PP_FPKM']
# <div class="pb" id="87a2ee07-55c7-470b-b58a-db7ab5f6ed46"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Susan: ('Bcd',):</td>
# <td class="pb_widget"><div id="2f1f3f33-33d1-4290-97d1-af2f967cae60">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="a379c983-2d44-485b-bb0d-c637f7a43fdd"></div>
#         <script type="text/javascript">
#             $("div#a379c983-2d44-485b-bb0d-c637f7a43fdd").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="2a6b769a-3d71-47ee-993e-fb15cd519879">ETA:  --:--:--</div></td>
# </tr></table><div>
# Best hit in  ../susan/by_cycle/cyc_14b.txt
# <div class="pb" id="036c72ef-e7e0-43d9-8a4e-e9523c6fb669"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 0:</td>
# <td class="pb_widget"><div id="012952e2-2947-4c33-92c0-8958ac818596">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="25a36412-bcdb-4b01-87a4-9f592aa60ad5"></div>
#         <script type="text/javascript">
#             $("div#25a36412-bcdb-4b01-87a4-9f592aa60ad5").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="76422dca-ddcd-4573-9adb-a42a9c0c462e">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 0
# Mode position [  9 104 330 246   0]
# Mean position [13.536321646977177, 106.3734341396505, 319.92437245593953, 255.56725936002169, 46.085002179366533]
# <div class="pb" id="d64ca25d-d9f0-4a69-a748-d5009102bb98"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 1:</td>
# <td class="pb_widget"><div id="493e1eba-c24d-4032-b99a-d961ff3e54f8">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="45745cc5-5457-4266-b8ac-895589bc4cdf"></div>
#         <script type="text/javascript">
#             $("div#45745cc5-5457-4266-b8ac-895589bc4cdf").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="02bd79a8-58bc-469e-b894-8a62ae0a2626">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 1
# Mode position [ 20 104 399   0 393]
# Mean position [17.272566040557887, 103.69312266685628, 348.24990630535558, 1.2200617378320349, 366.95630404118339]
# <div class="pb" id="407502fe-8569-40f8-9fbe-bcabd9ba93fd"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 2:</td>
# <td class="pb_widget"><div id="d36c3b06-0d38-4432-a20e-2ebe10b183fa">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="7a6500cd-3a60-498a-8369-e835fc91c570"></div>
#         <script type="text/javascript">
#             $("div#7a6500cd-3a60-498a-8369-e835fc91c570").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="521a6f51-e97f-44a1-9215-43834b487fc4">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 2
# Mode position [ 13 107 330   0 399]
# Mean position [14.014096514130216, 108.9418731906444, 339.63211885307328, 0.65933847537242285, 378.01598281253951]
# <div class="pb" id="dbc45ca5-43a9-4bf6-8850-40737c7b5faa"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 3:</td>
# <td class="pb_widget"><div id="e2236852-5331-43f7-872c-2bf0cca1a71f">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="bded8ba2-0e40-442d-b5f4-02a3be7b08d4"></div>
#         <script type="text/javascript">
#             $("div#bded8ba2-0e40-442d-b5f4-02a3be7b08d4").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="31dc9301-1f19-4eb0-9154-2eb52f309ef5">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 3
# Mode position [  0  55   0   0 399]
# Mean position [1.3087084585867133, 53.539599318176457, 233.86317778686302, 2.2380758224113046, 374.29444247484503]
# <div class="pb" id="f630e206-a0ff-4b0c-8b70-611237920e29"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 4:</td>
# <td class="pb_widget"><div id="e3997db8-221d-4644-9774-78f107a41761">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="22ff63d7-68fa-48d0-8b9c-fd0354e3fe9f"></div>
#         <script type="text/javascript">
#             $("div#22ff63d7-68fa-48d0-8b9c-fd0354e3fe9f").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="d10a62c5-b74f-4889-8ae0-efabd214786f">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 4
# Mode position [  2  81   0   0 395]
# Mean position [5.8315683490078865, 85.507034716150997, 44.956744212415771, 38.471929972636829, 391.4611670787948]
# <div class="pb" id="5e62eaf4-c382-43c5-82a0-daebc3cdd5a5"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 5:</td>
# <td class="pb_widget"><div id="b52a666c-3961-48f4-9ca5-ad8b40ddfc65">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="ac927a90-4699-425b-a890-1bd0929fd4f7"></div>
#         <script type="text/javascript">
#             $("div#ac927a90-4699-425b-a890-1bd0929fd4f7").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="435c8453-59be-4924-a3c5-21bc0f790e90">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 5
# Mode position [  0  61 399   0 394]
# Mean position [0.32755793580866177, 68.637550963025546, 395.01085729989779, 1.1464558694290934, 390.24606491320446]

# %% [markdown]
# Futzing with plotting
# ---------------------
#
#
# Thesis committee felt like just the peaks was confusing, so here's where I experimented to add the bars indicating positions

# %%
n_pos, n_samples = shape(priors)
mpl.cm.__getattribute__('jet')
print FPKM_cols
# Out:
# ['AAA_FPKM', 'AA_FPKM', 'A_FPKM', 'P_FPKM', 'PP_FPKM', 'PPP_FPKM']

# %%
args.colormap = 'gist_rainbow'
my_cm = mpl.cm.__getattribute__(args.colormap)
plots = []
for i in range(n_samples):
    plots.extend(mpl.plot(priors[:,i], label=FPKM_cols[i].replace('_FPKM', ''), color = my_cm(i * 256 / (n_samples+1))))
ax = mpl.gca()

Y = priors.max()
dY = 0.25 * Y
Y += dY
ests = [sum(np.arange(n_pos) * priors[:,i]) for i in range(6)]
for plot, x in zip(plots, ests):
    print "Rectangle at", (x, Y), (60, dY)
    mpl.vlines(x, plot.get_data()[1][x], Y+dY, edgecolor=plot.get_color(), linestyles='dotted')
    ax.add_artist(mpl.Rectangle((x, Y), 60, dY, facecolor=plot.get_color(), alpha=0.7))
    #Y += dY

mpl.title("Slice Position estimates")
mpl.xlabel("A/P position ($\\mu$m)")
mpl.ylabel("P(start @ $x\\pm1\\mu$m)")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

mpl.show()
# Out:
# Rectangle at (33.479003917819192, 0.14886308470266482) (60, 0.029772616940532966)
# Rectangle at (116.85068759931367, 0.14886308470266482) (60, 0.029772616940532966)
# Rectangle at (181.15498280770322, 0.14886308470266482) (60, 0.029772616940532966)
# Rectangle at (229.06233535398223, 0.14886308470266482) (60, 0.029772616940532966)
# Rectangle at (286.65687573716286, 0.14886308470266482) (60, 0.029772616940532966)
# Rectangle at (399.66566408479878, 0.14886308470266482) (60, 0.029772616940532966)

# %%
cm.jet(0)
# Out:
# (0.0, 0.0, 0.5, 1.0)

# %%
x = "('A', 'P')"
print x.translate(None,' \'(),"')
# Out:
# AP

# %% [markdown]
# Gold Standards
# --------------
#
# Thesis committee felt like I should feed the original data back in through itself,
# so I know exactly how well I can do. The concern was that the peak positions were
# too broad, and I had made a claim that at certain locations, it was simply harder to
# know.  I should take the initial data (both the FPKMs from Susan's set, and the BDTNP
# data), put it together in a way that it should match things very precisely, then see
# how well it actually does.  I'm less interested in how quickly it converges to the right
# time point, although if it doesn't converge pretty quickly, then there's a problem.

# %%
import pandas as pd
import PointClouds as pc

# %%
endswith_fpkm = lambda x: x.endswith('FPKM')

# %%
standard_posns = array([30,90,150,210,270,330])

# %%
shape(slices)
# Out:
# (420, 98, 6)

# %%
sel_slices = pd.DataFrame(slices[standard_posns, :, 4])

# %%
pcr = pc.PointCloudReader(open('../D_mel_wt_atlas_r2.vpc'))

# %%
sel_slices.index = ['Pos'+str(i)+'u_FPKM' for i in standard_posns]
sel_slices.columns = list(pcr.get_gene_names())

# %%
with_vals = sel_slices.transpose().dropna(how='any').select(lambda x: not x.endswith('P'))

# %%
susan = pd.read_table('../susan/by_cycle/cyc_14b.txt', index_col = 0)

# %%
with_vals = with_vals.select(lambda x: x in susan.index)
susan = susan.select(lambda x: x in with_vals.index)

# %%
mean_susan = np.mean(susan, axis=1)
std_susan = np.std(susan, axis=1)

# %%
ret = with_vals.copy()
mean_slices = mean(with_vals, axis=1)
for row in ret.index:
    ret.ix[row] /= mean_slices.ix[row]
#print mean(ret, axis=1)

# %%
ret_vals = with_vals.copy()
mean_vals = mean(ret_vals, axis=1)
for row in with_vals.index:
    ret_vals.ix[row] /= mean_vals.ix[row]
for column in with_vals.columns:
    ret_vals[column] *=  mean_susan
    hi_name = column.replace('FPKM', 'conf_hi')
    lo_name = column.replace('FPKM', 'conf_lo')
    ret_vals[hi_name] = ret_vals[column] * (mean_susan + 2 * std_susan) / mean_susan
    ret_vals[lo_name] = np.clip(ret_vals[column] * (mean_susan - 2* std_susan) / mean_susan, 0, np.Inf)

# %%
print mean_susan['gt']
mean(ret_vals.ix['gt'].select(lambda x: x.endswith('FPKM')))
# Out:
# 148.805
# 148.80500000000004

# %%
ret_vals.to_csv('../susan/FakeSlicesT4_cyc14b.expr', sep='\t', index_label='gene_short_name')

# %%
run ~/Documents/EisenLabStuff/Code/BayesMatch.py --set Pos ../susan/FakeSlicesT4_cyc14b.expr
# Out:
# ['Pos']
# [('Pos',)]
# ------------------------------------------------------------
#
# ('Pos',)
# ------------------------------------------------------------
# <div class="pb" id="ba9ae7a0-bcc9-4886-8f6e-f6bae6229cfe"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Susan: ('Pos',):</td>
# <td class="pb_widget"><div id="8e0d9de6-309a-4b4c-9547-289166e6294e">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="cd0e755b-23b9-4f44-b52e-27f9c6493ac0"></div>
#         <script type="text/javascript">
#             $("div#cd0e755b-23b9-4f44-b52e-27f9c6493ac0").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="55b46b18-01d8-4c72-9e72-74c332316e0b">ETA:  --:--:--</div></td>
# </tr></table><div>
# Best hit in  ../susan/by_cycle/cyc_14b.txt
# <div class="pb" id="46ddefbd-3f53-456f-852c-79fab708301c"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 0:</td>
# <td class="pb_widget"><div id="0bc61a47-beb6-470d-83ea-50add20f965d">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="6142662b-7a08-4735-9ee0-85b4d79f9928"></div>
#         <script type="text/javascript">
#             $("div#6142662b-7a08-4735-9ee0-85b4d79f9928").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="bc769c2f-6897-4158-b1b8-8f064ebc6198">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 0
# Mode position [ 55 263 184 273 263 156]
# Mean position [48.57228418396172, 259.93251733219705, 184.35103724348104, 266.50720654383042, 264.02256500443707, 244.08815414970186]
# <div class="pb" id="c2e5ee14-9b4a-43c0-9ddc-ba79b7e7562b"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 1:</td>
# <td class="pb_widget"><div id="ad66421f-254d-4803-a6d0-fc8880df5414">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="61246049-79fe-4b20-9585-4313b4b56ecb"></div>
#         <script type="text/javascript">
#             $("div#61246049-79fe-4b20-9585-4313b4b56ecb").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="82c0f7bd-578d-4d64-a28f-63bc2f20bf20">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 1
# Mode position [ 51 100 181 270 257 300]
# Mean position [51.910964519150433, 100.61846244673801, 182.303461410148, 260.66548634134119, 258.59745366351638, 297.8082337516413]
# <div class="pb" id="6dd13fdb-02f3-4152-aaae-b0ae4a982106"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 2:</td>
# <td class="pb_widget"><div id="4d06f4bf-3dd3-47a6-8946-9c66859cbf59">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="00540a33-dfc9-4392-9ad1-8992660c5f79"></div>
#         <script type="text/javascript">
#             $("div#00540a33-dfc9-4392-9ad1-8992660c5f79").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="c61777de-4c6d-4a66-8f04-cbe58228cf4f">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 2
# Mode position [ 54  99 181 273 261 304]
# Mean position [53.993534575121451, 105.54368530261664, 181.67909076607253, 259.86177046932647, 262.56296077602343, 301.75017734108411]
# <div class="pb" id="b0e8b50f-c69f-4300-9c5b-2b5c3e2762b5"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 3:</td>
# <td class="pb_widget"><div id="eaa9d77b-fc1c-447d-8aa4-7c9ff6b28288">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="698bce60-163a-484a-aa91-62fd7eae9223"></div>
#         <script type="text/javascript">
#             $("div#698bce60-163a-484a-aa91-62fd7eae9223").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="112d948f-eff9-4c91-9bce-2adee328d1a3">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 3
# Mode position [ 44 108 175 257 248 294]
# Mean position [43.870453367576708, 106.46316481845567, 171.96677657694028, 225.71318280079404, 245.00135564280791, 293.79713723311846]
# <div class="pb" id="f86ad220-478f-4c06-b914-013e2eba3629"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 4:</td>
# <td class="pb_widget"><div id="807773e4-3cc5-4cf4-b938-3969a0e0fc1b">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="e10c9f55-a839-4d63-b7ac-94faa20fc63e"></div>
#         <script type="text/javascript">
#             $("div#e10c9f55-a839-4d63-b7ac-94faa20fc63e").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="892d2cb1-df7a-4932-94dd-155559b489bd">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 4
# Mode position [ 44 108 175 175 248 296]
# Mean position [44.290746026363664, 106.51902717018629, 174.36140330478216, 195.89086562615608, 198.92969426683703, 295.14781646409705]
# <div class="pb" id="51e73c97-e9da-4aa3-8296-bfa4008d0239"><table class="pb ui-widget"><tr>
# <td class="pb_widget">Time 5:</td>
# <td class="pb_widget"><div id="99e2f69e-8857-4932-aada-762cc8d9a6d6">  0%</div></td>
# <td class="pb_widget_fill">
#         <div class="pb_bar" id="ca32893e-b6f3-4cc9-832f-cccb89dd37a2"></div>
#         <script type="text/javascript">
#             $("div#ca32893e-b6f3-4cc9-832f-cccb89dd37a2").progressbar({value: 0});
#         </script>
#         </td>
# <td class="pb_widget"><div id="4e614d30-e3e3-49c5-aa41-9c7b92640323">ETA:  --:--:--</div></td>
# </tr></table><div>
# In time slice 5
# Mode position [ 36 104 169 257 245 298]
# Mean position [36.272840145897604, 105.48638795969305, 170.89489951648312, 247.52585014194466, 244.2365625808755, 297.54611192179004]

# %%
gene = 'hb'
probs = [prob(frame.ix[gene], cycle.ix[gene]) for cycle in cycles]
print probs
print probs[cycnames.index('../susan/by_cycle/cyc_14b.txt')]
# Out:
# [1.7310708422257903e-11, 5.480727983675493e-07, 1.4830909845220397e-05, 5.113970681547286e-05, 0.1112675461839171, 0.44613628274338457, 4.7218097691592575e-05, 0.0]
# 0.446136282743

# %%
for cycle in cycles:
    print cycle.ix[gene]
    print '-'*60
# Out:
# F10    108.56
# M10    117.06
# Name: hb
# ------------------------------------------------------------
# F11    134.20
# M11    142.47
# Name: hb
# ------------------------------------------------------------
# F12    132.32
# M12    111.45
# Name: hb
# ------------------------------------------------------------
# U13    157.48
# M13    149.93
# Name: hb
# ------------------------------------------------------------
# F14A       193.37
# U14A       153.77
# M14A       182.16
# M14A_r2    179.98
# Name: hb
# ------------------------------------------------------------
# F14B       202.16
# F14B_r2    320.59
# M14B       184.94
# M14B_r2    274.81
# Name: hb
# ------------------------------------------------------------
# F14C        66.01
# F14C_r2    107.23
# M14C        44.74
# M14C_r2     88.29
# Name: hb
# ------------------------------------------------------------
# F14D       47.43
# U14D       58.05
# M14D       49.75
# M14D_r2    32.87
# Name: hb
# ------------------------------------------------------------

# %%
gt = frame.ix[gene]
print gt.select(endswith_fpkm)

print mean(gt.select(endswith_fpkm))
# Out:
# Pos30u_FPKM      79.685384
# Pos90u_FPKM     248.872515
# Pos150u_FPKM    256.713873
# Pos210u_FPKM    199.234757
# Pos270u_FPKM    126.721938
# Pos330u_FPKM    562.521532
# Name: hb
# 245.625

# %%
with_vals.ix[gene]
# Out:
# Pos30u_FPKM      46.068080
# Pos90u_FPKM     143.879320
# Pos150u_FPKM    148.412602
# Pos210u_FPKM    115.182512
# Pos270u_FPKM     73.261068
# Pos330u_FPKM    325.207529
# Name: hb

# %%
T4 = slice_frames[4].dropna(how='any')

# %%
print frame.ix[gene].select(endswith_fpkm)
# Out:
# Pos30u_FPKM      79.685384
# Pos90u_FPKM     248.872515
# Pos150u_FPKM    256.713873
# Pos210u_FPKM    199.234757
# Pos270u_FPKM    126.721938
# Pos330u_FPKM    562.521532
# Name: hb

# %%
print gene
normed = (T4.ix[gene] / mean(T4.ix[gene]) * np.mean(best_cycle.ix[gene], axis=1))
normed.plot()
for val in frame.ix[gene].select(endswith_fpkm):
    hlines(val, 0, 450)
for col in FPKM_cols:
    figure()
    std = get_std(col, frame)
    evidence = stats.zprob(-np.abs((normed - frame[col][gene])/(std + 1)))
    evidence.plot()
    title(col)
# Out:
# hb

# %%
arange(450)[array([[1,2,3],[3,4,5],[6,7,8]])]
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [6, 7, 8]])

# %%
l = len(T4.ix[gene])
l
riffle = (vstack([arange(l)]*(1 + l//60)) % 60 + reshape(arange(0,l, 60), (l//60+1, 1))) % l

# %%
riffle.max()
# Out:
# 474

# %%
for gene in T4.index:
    rifres = mean(array(T4.ix[gene])[riffle], axis=0)
    print gene, rifres.min(), mean(T4.ix[gene]), rifres.max()
# Out:
# gt 142.279630625 144.161443423 143.637578
# gtP 233.5058845 236.933152909 235.575736875
# CG8147 175.7134755 178.488036189 177.33133175
# CG17786 154.218114 156.7942758 156.217668625
# gk 265.658831125 269.827847914 268.1653875
# tsh 132.3323355 134.616775943 134.005885125
# slp1 136.102535375 139.706972234 140.012798625
# slp2 197.373390875 200.839464432 200.28365475
# D 195.05411475 197.279929196 195.407025375
# comm2 305.476476625 310.235771166 308.513954
# dan 240.12318675 243.101028284 241.4262735
# NetA 216.15732725 219.863709314 218.81714875
# tkv 226.17205225 230.563364105 230.51628375
# emc 184.315171375 187.580137472 187.620929875
# trn 210.8945195 216.874225145 217.129671
# h 204.91315325 208.005449491 207.29392025
# eve 194.8118385 197.001561282 195.08520175
# disco 273.6014745 279.408044345 278.88491625
# Mdr49 189.6267265 196.801290244 199.260318375
# dpn 203.8707815 206.521167589 204.849837875
# CG10924 132.094749375 134.56355888 134.201245125
# htl 161.563043625 164.531597838 163.834786375
# Ilp4 122.493384125 125.331671259 125.190244625
# MESR3 159.717867375 162.542210341 161.91926
# jumu 302.820216375 313.636282019 316.720553
# pxb 287.21239275 295.22348552 296.407061
# odd 152.227786625 157.443916798 157.8361895
# croc 121.5237435 127.354601581 130.191939625
# CG8965 175.15464325 178.231724581 177.5701635
# ftz 211.941217375 214.347171579 212.29544525
# ImpE2 120.080260375 129.639520596 134.293689625
# cnc 129.3249475 134.122635164 137.10514875
# peb 120.843594625 123.372493124 123.310898
# ken 161.15301375 165.378060141 165.941314875
# CG31670 224.084359375 228.809467238 228.7836895
# hkb 106.239673 111.215744827 113.463991
# path 208.890956 213.853568636 214.776608625
# hbP 303.15367575 309.448046524 309.443666625
# KrP 171.8806965 174.437330952 173.36186525
# oc 76.27309475 77.8821653389 77.867571875
# mfas 248.364378875 252.581619619 251.391804875
# srp 180.952998625 186.466415627 187.28998925
# Bsg25A 173.619171875 177.4167154 177.425012625
# tll 69.595712375 70.5446985368 70.05623125
# sob 335.55214925 343.754070282 343.976392625
# rho 138.27695275 140.247204855 139.244125
# apt 120.964196125 123.588327579 123.656236125
# brk 247.568292 251.552156579 250.289040125
# Doc2 116.33640625 118.704720977 118.370945875
# CG31607 125.60869525 128.206677086 128.503859875
# Dfd 309.671390125 315.919698131 315.6287045
# Traf1 134.370207 137.068574095 136.570145125
# Nek2 196.4938555 199.407615886 198.634845125
# Btk29A 155.52972075 159.263208846 159.701643
# Ama 253.08008725 257.815786857 256.885142125
# twi 163.056791625 168.924503918 170.172516
# Cyp310a1 204.913684 210.415052676 211.00127625
# toc 118.07799525 122.461232032 124.631895375
# Ance 96.024938375 97.6163817789 97.194329875
# bmm 203.47171025 207.615014678 207.2905185
# Kr 100.611669 102.027792543 101.300402875
# bun 162.012982625 165.315095335 165.04837
# hb 116.44734725 118.165099956 117.512974875
# Mes2 131.269697625 133.872295472 133.594620125
# danr 321.345162875 326.128270051 325.237197
# nub 110.75112175 112.989909156 112.7436985
# sala 220.535115375 224.230571937 223.10807125
# aay 69.6140785 70.8574945916 70.575490375
# cad 196.468585625 199.297594827 198.11583075
# prd 196.754443875 199.338577916 197.88326375
# CG17724 239.860187 245.376580495 245.710580625
# Esp 271.596172625 276.693886604 275.77547225
# rib 221.84443575 231.237411556 233.50419925
# fkh 81.396185625 85.2285544568 85.975900625
# Blimp-1 216.521396625 221.368039665 222.085899
# CG11208 207.26498175 212.032293916 212.67975925
# chrb 191.97949175 197.010488181 197.86067275
# sna 132.071636125 134.99007744 134.945866125
# knrl 144.542161875 153.615261752 157.692171625
# numb 180.01395725 183.8541182 184.446974375
# CG14427 161.296338875 166.562548114 167.927998
# fj 165.461984875 168.886831038 168.534890375
# Alh 228.630648375 233.010080055 232.303782625
# kni 177.271341625 186.251704048 189.93995375
# CG10479 235.826038375 240.401916905 240.28810125
# Doc3 254.231210875 259.707197718 259.31402

# %%
print mean(T4.ix[gene])
# Out:
# 118.165099956

# %% [markdown]
# $$e^{i \pi} = -1$$
